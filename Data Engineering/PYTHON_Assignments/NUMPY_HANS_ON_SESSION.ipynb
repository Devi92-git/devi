# %%
import numpy as np

# %%
data=np.random.randint(0,10,(3,3))

# %%
data
# Out:
# array([[0, 5, 8],
#        [3, 2, 6],
#        [2, 9, 7]])

# %%
data.sum(axis=0),data.sum(axis=1),data.sum()
data.min(axis=0),data.min(axis=1),data.min()
data.max(axis=0),data.max(axis=1),data.max()
data.argmin(axis=0),data.argmin(axis=1),data.argmin()
data.argmax(axis=0),data.argmax(axis=1),data.argmax()
data.mean(axis=0),data.mean(axis=1),data.mean()

# %%
data.sum(axis=0)
# Out:
# array([ 5, 16, 21])

# %%
data.sum(axis=1)
# Out:
# array([13, 11, 18])

# %%
data.min(axis=0)
# Out:
# array([0, 2, 6])

# %%
data.min(axis=1)
# Out:
# array([0, 2, 2])

# %%
data.min()
# Out:
# np.int64(0)

# %%
data.max(axis=0)
# Out:
# array([3, 9, 8])

# %%
data.max(axis=1)
# Out:
# array([8, 6, 9])

# %%
data.max()
# Out:
# np.int64(9)

# %%
data.argmin(axis=0)
# Out:
# array([0, 1, 1])

# %%
data.argmin(axis=1)
# Out:
# array([0, 1, 0])

# %%
data.argmin()
# Out:
# np.int64(0)

# %%
data.argmax(axis=0)
# Out:
# array([1, 2, 0])

# %%
data.argmax(axis=1)
# Out:
# array([2, 2, 1])

# %%
data.argmax()
# Out:
# np.int64(7)

# %%
data.mean(axis=0)
# Out:
# array([1.66666667, 5.33333333, 7.        ])

# %%
data.mean(axis=1)
# Out:
# array([4.33333333, 3.66666667, 6.        ])

# %%
data.mean()
# Out:
# np.float64(4.666666666666667)
